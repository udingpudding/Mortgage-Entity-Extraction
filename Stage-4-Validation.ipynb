# %% [markdown]
# # Imports and Installs

# %%
# !pip install fuzzywuzzy
# !pip install python-Levenshtein
# !pip install jaro-winkler
# Out:
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0
# Collecting python-Levenshtein
#   Downloading python_Levenshtein-0.26.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting Levenshtein==0.26.1 (from python-Levenshtein)
#   Downloading levenshtein-0.26.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Collecting rapidfuzz<4.0.0,>=3.9.0 (from Levenshtein==0.26.1->python-Levenshtein)
#   Downloading rapidfuzz-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Downloading python_Levenshtein-0.26.1-py3-none-any.whl (9.4 kB)
# Downloading levenshtein-0.26.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 3.5 MB/s eta 0:00:00
# Downloading rapidfuzz-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 15.3 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, Levenshtein, python-Levenshtein
# Successfully installed Levenshtein-0.26.1 python-Levenshtein-0.26.1 rapidfuzz-3.10.1
# Collecting jaro-winkler
#   Downloading jaro_winkler-2.0.3-py3-none-any.whl.metadata (2.6 kB)
# Downloading jaro_winkler-2.0.3-py3-none-any.whl (33 kB)
# Installing collected packages: jaro-winkler
# Successfully installed jaro-winkler-2.0.3

# %%
import pandas as pd
import numpy as np

import fuzzywuzzy
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import jaro

# %% [markdown]
# # Utils/Helper Functions

# %%
#gives average document similarity for model
#gives the similarity average across each feature
#store scores in a matrix
#add sorting and all for a


def validate(df1, df2, metric):

  matrix = []

  if len(df1) != len(df2): #check if DFs are unequal, in this case overlapping docs will be extracted
    print('Unequal DFs')

  else:
    for row in range(0,len(df1)): #for each row (doc) in the DFs
      row_vector = [] #to store row scores (doc)
      for cell1, cell2 in zip(list(df1.iloc[row]), list(df2.iloc[row])): #for each corresponding cell (feature entity) in a document
        cell1, cell2 = str(cell1), str(cell2) #string conversion for N/A handling
        score = metric(cell1, cell2) #calculating score between each corresponding entity
        row_vector.append(score) #appending score to the row_vector (holding similarity for all features in a doc)
      matrix.append(row_vector) #appending vector to the matrix of scores


  matrix = np.array(matrix) #converting to np array
  overall = np.mean(matrix) #overall score

  document_means = [np.mean(row) for row in matrix] # collecting means bw each doc
  document_dict = dict(zip(df1['Document_Name'], document_means)) #conversion to dict
  document_df = pd.DataFrame.from_dict(document_dict, orient='index', columns=['Score']).reset_index() #document df
  document_df.columns = ['Document', 'Score'] #renaming cols


  feature_means = [np.mean(col) for col in matrix.T] #collecting means bw each feature across doc
  feature_dict = dict(zip(df1.columns, feature_means)) #conversion to dict
  feature_df = pd.DataFrame.from_dict(feature_dict, orient='index', columns=['Score']).reset_index() #feature df
  feature_df.columns = ['Feature', 'Score'] #renaming cols



  return matrix, document_df, feature_df, overall #returning all

# %%
matrix, document_df, feature_df, overall = validate(df_4o, df_4o_mini, fuzz.partial_ratio)
matrix
# Out:
# array([[100, 100, 100, 100, 100, 100, 100, 100, 100, 100,  99,  88, 100],
#        [100, 100, 100, 100, 100, 100, 100,  30, 100, 100,  97,  79, 100],
#        [100,   0,   0, 100, 100, 100, 100, 100, 100, 100,  94,  93, 100],
#        [100,   0,  25,   0,   0,   0,   0,  32, 100,  80,  90,  96, 100],
#        [100, 100, 100, 100, 100,   0, 100, 100, 100, 100,  99, 100, 100],
#        [100,   0, 100,   0, 100, 100, 100, 100, 100, 100, 100,  61, 100],
#        [100, 100, 100, 100, 100, 100, 100, 100,  25, 100, 100,  86, 100],
#        [ 86,   0,   0, 100, 100,   0,   0,  19, 100, 100, 100,  70, 100],
#        [  0,   0,  33, 100, 100,   0,  33,  16, 100, 100, 100,  69, 100],
#        [ 89,  40,  25, 100, 100,  40,  17, 100, 100, 100,  99, 100, 100],
#        [100, 100, 100,  25,  14, 100,  17,  45, 100, 100, 100,  68, 100],
#        [ 78, 100, 100, 100, 100, 100, 100, 100, 100, 100,  99, 100, 100],
#        [100, 100, 100, 100, 100, 100, 100,  32, 100, 100, 100,  94, 100],
#        [100,   0,  67, 100, 100,  50,  17,  31, 100, 100,  99,  64, 100],
#        [100, 100, 100, 100, 100, 100, 100,  23, 100, 100, 100,  82, 100],
#        [ 89, 100, 100, 100, 100, 100, 100, 100,  25, 100, 100,  70, 100],
#        [100, 100, 100, 100, 100,   0,   0,  33, 100, 100,  96, 100, 100],
#        [100, 100,  80,  33,   0,  33,  33, 100, 100,  80,  95,  88, 100],
#        [ 89, 100, 100, 100, 100, 100, 100,  32, 100, 100, 100,  77, 100],
#        [100, 100, 100, 100, 100,   0, 100, 100,  25, 100,  93,  76, 100],
#        [  0, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100,  66, 100],
#        [100, 100, 100, 100, 100, 100, 100, 100, 100,   0, 100, 100, 100],
#        [100, 100,  12, 100, 100, 100,  25,  29, 100, 100, 100,  53, 100],
#        [100,   0,  50, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100],
#        [100,   0,  50, 100, 100,  14,  14, 100, 100, 100, 100,  86, 100]])

# %%
document_df
# Out:
#                   Document      Score
# 0         4201768_0001.tif  99.000000
# 1         4204010_0001.tif  92.769231
# 2         4302425_0001.tif  83.615385
# 3         4202463_0001.tif  47.923077
# 4         4306466_0001.tif  92.230769
# 5         4302583_0001.tif  81.615385
# 6         4306964_0001.tif  93.153846
# 7         4205888_0001.tif  59.615385
# 8   48167_4000820_0001.tif  57.769231
# 9         4004912_0001.tif  77.692308
# 10        4105565_0001.tif  74.538462
# 11        4005813_0001.tif  98.230769
# 12        4104165_0001.tif  94.307692
# 13        4307340_0001.tif  71.384615
# 14        4005318_0001.tif  92.692308
# 15        4004575_0001.tif  91.076923
# 16        4306607_0001.tif  79.153846
# 17        4004046_0001.tif  72.461538
# 18        4104592_0001.tif  92.153846
# 19        4305776_0001.tif  84.153846
# 20        4104649_0001.tif  89.692308
# 21        4005800_0001.tif  92.307692
# 22        4203323_0001.tif  78.384615
# 23        4307353_0001.tif  88.461538
# 24        4307375_0001.tif  74.153846

# %%
feature_df
# Out:
#                   Feature   Score
# 0                    Date   89.24
# 1          Borrower_First   65.60
# 2           Borrower_Last   73.68
# 3   Second_Borrower_First   86.32
# 4    Second_Borrower_Last   88.56
# 5       Other_Party_First   65.48
# 6        Other_Party_Last   66.24
# 7            Lending_Bank   68.88
# 8           Interest_Rate   91.00
# 9             Loan_Amount   94.40
# 10  Location_for_Mortgage   98.40
# 11           Payment_Plan   82.64
# 12          Document_Name  100.00

# %%
df = pd.DataFrame.from_dict(feature_means, orient='index', columns=['Score']).reset_index()
df
# Out:
#                     index   Score
# 0                    Date   89.36
# 1          Borrower_First   63.12
# 2           Borrower_Last   66.40
# 3   Second_Borrower_First   85.72
# 4    Second_Borrower_Last   88.56
# 5       Other_Party_First   57.88
# 6        Other_Party_Last   59.44
# 7            Lending_Bank   67.88
# 8           Interest_Rate   92.80
# 9             Loan_Amount   89.04
# 10  Location_for_Mortgage   83.60
# 11           Payment_Plan   78.36
# 12          Document_Name  100.00

# %%
list(df_4o.iloc[0])
# Out:
# ['28/10/1941',
#  'Palmer',
#  'Haynes',
#  'Ilene',
#  'Haynes',
#  'R. M.',
#  'Orth',
#  'THE TEXAS CITY NATIONAL BANK',
#  '4.5%',
#  '$2,750.00',
#  "The East Twenty-five Feet (E-25') of Lot numbered. Four (4) and all of Lot Five (5), Block numbered Three Hundred Seventy-nine (379), Texas City Fourth bivision, according to plat thereof recorded in Book 238, Page 21, of the records of Galveston County, Texas.",
#  'Monthly payments of $21.04, including interest, commencing on May 1, 1942, and continuing until the principal and interest are fully paid, with the final payment due on November 1, 1957.',
#  '4201768_0001.tif']

# %%
matrix[:, 1]
# Out:
# array([ 80, 100,   0,   0, 100,   0, 100,   0,   0,  31, 100, 100, 100,
#          0, 100, 100, 100, 100, 100, 100,  67, 100, 100,   0,   0])

# %% [markdown]
# # Loading CSVs

# %%
#df_llama= pd.read_csv("/content/llama_doctr.csv")


df_4o = pd.read_csv("/content/4o_doctr.csv")
df_4o_confidence = pd.read_csv("/content/df_4o_confidence_csv.csv")
df_4o_confidence_all = pd.read_csv("/content/df_4o_confidence_all_csv.csv")

df_4o_mini= pd.read_csv("/content/4o_mini_doctr.csv")
df_4o_mini_confidence = pd.read_csv("/content/df_4o_mini_confidence_csv.csv")
df_4o_mini_confidence_all = pd.read_csv("/content/output_4o_mini_confidence_all_csv.csv")


df_mistral = pd.read_csv("/content/mistral_doctr.csv")
df_mistral_confidence = pd.read_csv("/content/output_mistral_confidence_csv.csv")

df_kate = pd.read_csv("/content/kate_llm.csv")

df_newline = pd.read_csv("/content/newline_4o_mini_csv.csv")

# %%
df_4o_two_page = pd.read_csv("/content/twopage_df_4o_confidence_final_csv.csv")
df_4o_two_page_refinal= pd.read_csv("/content/twopage_df_4o_confidence_refinal_csv.csv")
df_4o_two_page_re_refinal= pd.read_csv("/content/twopage_df_4o_confidence_re_refinal_csv.csv")

df_4o_mini_two_page = pd.read_csv("/content/twopage_df_4o_mini_confidence_final_csv.csv")
df_4o_mini_two_page_refinal= pd.read_csv("/content/twopage_df_4o_mini_confidence_refinal_csv.csv")

df_mistral_two_page = pd.read_csv("/content/twopage_df_mistral_confidence_final_csv.csv")

df_kate = pd.read_csv("/content/kate_llm.csv")

# %% [markdown]
# ## Two Mortgage Feature Validation

# %%
ground_truth = pd.read_csv('/content/ground_truth_two_mortgages.csv')
ground_truth = ground_truth[['Document', 'Two_Mortgage']]

# %%
ground_truth
# Out:
#                   Document Two_Mortgage
# 0         4004046_0001.tif           No
# 1         4004575_0001.tif          Yes
# 2         4004912_0001.tif          Yes
# 3         4005318_0001.tif          Yes
# 4         4005800_0001.tif          Yes
# 5         4005813_0001.tif          Yes
# 6         4104165_0001.tif           No
# 7         4104592_0001.tif           No
# 8         4104649_0001.tif           No
# 9         4105565_0001.tif           No
# 10        4201768_0001.tif           No
# 11        4202463_0001.tif           No
# 12        4203323_0001.tif           No
# 13        4204010_0001.tif           No
# 14        4205888_0001.tif           No
# 15        4302425_0001.tif           No
# 16        4302583_0001.tif          Yes
# 17        4305776_0001.tif           No
# 18        4306466_0001.tif          Yes
# 19        4306607_0001.tif          Yes
# 20        4306964_0001.tif           No
# 21        4307340_0001.tif           No
# 22        4307353_0001.tif           No
# 23        4307375_0001.tif           No
# 24  48167_4000820_0001.tif           No

# %%
preds_4o = df_4o_two_page[['Document_Name', 'Two_Mortgages']]
preds_4o_mini = df_4o_mini_two_page[['Document_Name', 'Two_Mortgages']]
preds_mistral = df_mistral_two_page[['Document_Name', 'Two_Mortgages']]

# %%
preds_4o = preds_4o.sort_values(by = ['Document_Name']).reset_index(drop=True)
preds_4o_mini = preds_4o_mini.sort_values(by = ['Document_Name']).reset_index(drop=True)
preds_mistral = preds_mistral.sort_values(by = ['Document_Name']).reset_index(drop=True)
ground_truth = ground_truth.sort_values(by = ['Document']).reset_index(drop=True)

# %%
comparision_df = pd.concat([preds_4o.Document_Name,
                            preds_4o_mini.Document_Name,
                            preds_mistral.Document_Name,
                            ground_truth.Document,
                            preds_4o.Two_Mortgages,
                            preds_4o_mini.Two_Mortgages,
                            preds_mistral.Two_Mortgages,
                            ground_truth.Two_Mortgage], axis = 1)

comparision_df.columns = ['Doc1', 'Doc2', 'Doc3','Doc4', '4o', '4o_Mini','Mistral', 'True']
comparision_df
# Out:
#                       Doc1                    Doc2                    Doc3  \
# 0         4004046_0001.tif        4004046_0001.tif        4004046_0001.tif
# 1         4004575_0001.tif        4004575_0001.tif        4004575_0001.tif
# 2         4004912_0001.tif        4004912_0001.tif        4004912_0001.tif
# 3         4005318_0001.tif        4005318_0001.tif        4005318_0001.tif
# 4         4005800_0001.tif        4005800_0001.tif        4005800_0001.tif
# 5         4005813_0001.tif        4005813_0001.tif        4005813_0001.tif
# 6         4104165_0001.tif        4104165_0001.tif        4104165_0001.tif
# 7         4104592_0001.tif        4104592_0001.tif        4104592_0001.tif
# 8         4104649_0001.tif        4104649_0001.tif        4104649_0001.tif
# 9         4105565_0001.tif        4105565_0001.tif        4105565_0001.tif
# 10        4201768_0001.tif        4201768_0001.tif        4201768_0001.tif
# 11        4202463_0001.tif        4202463_0001.tif        4202463_0001.tif
# 12        4203323_0001.tif        4203323_0001.tif        4203323_0001.tif
# 13        4204010_0001.tif        4204010_0001.tif        4204010_0001.tif
# 14        4205888_0001.tif        4205888_0001.tif        4205888_0001.tif
# 15        4302425_0001.tif        4302425_0001.tif        4302425_0001.tif
# 16        4302583_0001.tif        4302583_0001.tif        4302583_0001.tif
# 17        4305776_0001.tif        4305776_0001.tif        4305776_0001.tif
# 18        4306466_0001.tif        4306466_0001.tif        4306466_0001.tif
# 19        4306607_0001.tif        4306607_0001.tif        4306607_0001.tif
# 20        4306964_0001.tif        4306964_0001.tif        4306964_0001.tif
# 21        4307340_0001.tif        4307340_0001.tif        4307340_0001.tif
# 22        4307353_0001.tif        4307353_0001.tif        4307353_0001.tif
# 23        4307375_0001.tif        4307375_0001.tif        4307375_0001.tif
# 24  48167_4000820_0001.tif  48167_4000820_0001.tif  48167_4000820_0001.tif
#
#                       Doc4   4o 4o_Mini Mistral True
# 0         4004046_0001.tif   No      No      No   No
# 1         4004575_0001.tif   No      No      No  Yes
# 2         4004912_0001.tif  Yes     Yes     Yes  Yes
# 3         4005318_0001.tif   No      No      No  Yes
# 4         4005800_0001.tif   No      No      No  Yes
# 5         4005813_0001.tif   No     Yes      No  Yes
# 6         4104165_0001.tif   No      No      No   No
# 7         4104592_0001.tif   No      No      No   No
# 8         4104649_0001.tif   No      No      No   No
# 9         4105565_0001.tif   No      No      No   No
# 10        4201768_0001.tif   No      No      No   No
# 11        4202463_0001.tif   No      No      No   No
# 12        4203323_0001.tif   No      No      No   No
# 13        4204010_0001.tif   No      No      No   No
# 14        4205888_0001.tif   No      No      No   No
# 15        4302425_0001.tif   No      No      No   No
# 16        4302583_0001.tif  Yes      No      No  Yes
# 17        4305776_0001.tif   No      No      No   No
# 18        4306466_0001.tif  Yes     Yes      No  Yes
# 19        4306607_0001.tif  Yes     Yes      No  Yes
# 20        4306964_0001.tif   No      No      No   No
# 21        4307340_0001.tif   No      No      No   No
# 22        4307353_0001.tif   No      No      No   No
# 23        4307375_0001.tif   No      No      No   No
# 24  48167_4000820_0001.tif   No      No      No   No

# %%
comparision_df = comparision_df[['Doc1', '4o', '4o_Mini', 'Mistral', 'True']]
comparision_df
# Out:
#                       Doc1   4o 4o_Mini Mistral True
# 0         4004046_0001.tif   No      No      No   No
# 1         4004575_0001.tif   No      No      No  Yes
# 2         4004912_0001.tif  Yes     Yes     Yes  Yes
# 3         4005318_0001.tif   No      No      No  Yes
# 4         4005800_0001.tif   No      No      No  Yes
# 5         4005813_0001.tif   No     Yes      No  Yes
# 6         4104165_0001.tif   No      No      No   No
# 7         4104592_0001.tif   No      No      No   No
# 8         4104649_0001.tif   No      No      No   No
# 9         4105565_0001.tif   No      No      No   No
# 10        4201768_0001.tif   No      No      No   No
# 11        4202463_0001.tif   No      No      No   No
# 12        4203323_0001.tif   No      No      No   No
# 13        4204010_0001.tif   No      No      No   No
# 14        4205888_0001.tif   No      No      No   No
# 15        4302425_0001.tif   No      No      No   No
# 16        4302583_0001.tif  Yes      No      No  Yes
# 17        4305776_0001.tif   No      No      No   No
# 18        4306466_0001.tif  Yes     Yes      No  Yes
# 19        4306607_0001.tif  Yes     Yes      No  Yes
# 20        4306964_0001.tif   No      No      No   No
# 21        4307340_0001.tif   No      No      No   No
# 22        4307353_0001.tif   No      No      No   No
# 23        4307375_0001.tif   No      No      No   No
# 24  48167_4000820_0001.tif   No      No      No   No

# %%
correct_4o = len([item1 for item1, item2 in zip(comparision_df['4o'], comparision_df['True']) if item1 == item2])
correct_4o_mini = len([item1 for item1, item2 in zip(comparision_df['4o_Mini'], comparision_df['True']) if item1 == item2])
correct_mistral = len([item1 for item1, item2 in zip(comparision_df['Mistral'], comparision_df['True']) if item1 == item2])



accuracy_4o = correct_4o/25
accuracy_4o_mini = correct_4o_mini/25
accuracy_mistral = correct_mistral/25

total_positive = len([item for item in comparision_df['True'] if item =='Yes'])
total_negative = len([item for item in comparision_df['True'] if item =='No'])



tp_4o = len([item1 for item1, item2 in zip(comparision_df['4o'], comparision_df['True']) if item2 == 'Yes' and item1 == item2])
tp_4o_mini = len([item1 for item1, item2 in zip(comparision_df['4o_Mini'], comparision_df['True']) if item2 == 'Yes' and item1 == item2])
tp_mistral = len([item1 for item1, item2 in zip(comparision_df['Mistral'], comparision_df['True']) if item2 == 'Yes' and item1 == item2])


fp_4o = len([item1 for item1, item2 in zip(comparision_df['4o'], comparision_df['True']) if item2 == 'No' and item1 != item2])
fp_4o_mini = len([item1 for item1, item2 in zip(comparision_df['4o_Mini'], comparision_df['True']) if item2 == 'No' and item1 != item2])
fp_mistral = len([item1 for item1, item2 in zip(comparision_df['Mistral'], comparision_df['True']) if item2 == 'No' and item1 != item2])


tpr_4o = tp_4o/total_positive
tpr_4o_mini = tp_4o_mini/total_positive
tpr_mistral = tp_mistral/total_positive

fpr_4o = fp_4o/total_negative
fpr_4o_mini = fp_4o_mini/total_negative
fpr_mistral = fp_mistral/total_negative

# %%
correct_mistral
# Out:
# 18

# %%
print(accuracy_4o)
print(accuracy_4o_mini)
print(accuracy_mistral)
# Out:
# 0.84
# 0.84
# 0.72

# %%
print(tpr_4o)
print(tpr_4o_mini)
print(tpr_mistral)
# Out:
# 0.5
# 0.5
# 0.125

# %%
print(fpr_4o)
print(fpr_4o_mini)
print(fpr_mistral)
# Out:
# 0.0
# 0.0
# 0.0

# %%
precision_4o = tpr_4o/tpr_4o+fpr_4o
precision_4o_mini = tpr_4o_mini/tpr_4o_mini+fpr_4o_mini
precision_mistral = tpr_mistral/tpr_mistral+fpr_mistral

print(precision_4o)
print(precision_4o_mini)
print(precision_mistral)
# Out:
# 1.0
# 1.0
# 1.0

# %% [markdown]
# Total Positive - 8 (5 Strong, 3 Mild)
#
# 4o - 4 correct (3 Strong, 1 Mild) - 50% TPR, 60% Strong
#
# 4o_Mini 4 correct (4 Strong) - 50% TPR, 80% Strong

# %% [markdown]
# #Feature Validation

# %%
columns = list(df_4o_confidence.columns)
columns.remove('Confidence_Score')

# %%
df_4o_two_page
# Out:
#           Date    Borrower_First Borrower_Last Second_Borrower_First  \
# 0          NaN               NaN           NaN                   NaN
# 1          NaN               NaN           NaN                   NaN
# 2     1/3/1935             L. B.        Berndt            Mary Ellen
# 3     6/4/1942            George       Clayton                   NaN
# 4          NaN  Clarence Francis         Quinn              Kathleen
# 5          NaN               NaN           NaN                   NaN
# 6          NaN               NaN           NaN                   NaN
# 7          NaN             R. V.      MOCAULEY                   NaN
# 8     3/8/1942     Elmer Douglas        Laiche            Edna Pearl
# 9   21/03/1942         Palmer T.        Haynes                 Ilene
# 10   10/6/1941              Carl          Rust                 Louie
# 11         NaN                A.    Loore, Jr.                 Label
# 12   16/9/1940            Ernest        Wenzel                 Rosie
# 13   18/4/1939            Thomas  Higginbotham                 Hazel
# 14  28/05/1941          Margaret         Noble                   NaN
# 15  17/07/1941      Marvin Burke       Peeples               Lela G.
# 16   19/1/1942            Louise          Cook                 J. T.
# 17  31/10/1940          Lawrence       McLaren                Louise
# 18  12/11/1943               NaN           NaN                   NaN
# 19         NaN               NaN           NaN                   NaN
# 20    1/2/1942               NaN           NaN                   NaN
# 21  29/10/1940             C. A.      Robinson                Bessie
# 22   8/10/1940            Vester         Roper                 Naomi
# 23         NaN               NaN           NaN                   NaN
# 24   3/11/1943               NaN           NaN                   NaN
#
#    Second_Borrower_Last Other_Party_First           Other_Party_Last  \
# 0                   NaN             J. L.  MARTIN INVESTMENT COMPANY
# 1                   NaN              J.G.                    Estwood
# 2                Berndt            Wm. S.                    Bradley
# 3                   NaN             R. M.                       Orth
# 4                 Quinn             B. B.                     Yeager
# 5                   NaN              J.E.                Aosashe Jr.
# 6                   NaN               NaN                        NaN
# 7                   NaN             R. M.                       ORTH
# 8                Laiche             R. M.                       Orth
# 9                Haynes             R. M.                       Orth
# 10               Godard              Earl                      Wyatt
# 11                Acore        Carroll L.                      Jones
# 12               Wenzel           Johnnie                     Chuoke
# 13         Higginbotham             T. J.                     Bettes
# 14                  NaN             I. M.                       Orth
# 15              Peeples            Arthur                  Grigg Jr.
# 16                 Cook             W. E.                      White
# 17              McLaren             Harry                      Ninde
# 18                  NaN             J. G.                   Hestwood
# 19                  NaN                J.                   Hestwood
# 20                  NaN             J. L.  Martin Investment Company
# 21             Robinson             T. J.                     Bettes
# 22                Roper           Carroll                      Jones
# 23                  NaN               NaN                        NaN
# 24                  NaN                J.                D. Townsend
#
#                                    Lending_Bank Interest_Rate Loan_Amount  \
# 0       FIRST MORTGAGE COMPANY OF HOUSTON, INC.          4.5%    $3900.00
# 1       First Mortgage Company of Houston, Inc.          4.5%    $3550.00
# 2               Mortgage Investment Corporation          4.5%    $4600.00
# 3                      Texas City National Bank          4.5%   $3,000.00
# 4             Gulf Coast Investment Corporation          4.5%   $4,400.00
# 5                      J. E. FOSTER & SON, INC.          4.5%   $3,950.00
# 6       First Mortgage Company of Houston, Inc.          4.5%   $4,950.00
# 7                      TEXAS CITY NATIONAL BANK          4.5%   $3,250.00
# 8                       The Texas National Bank            4%    $3000.00
# 9                  The Texas City National Bank          4.5%   $2,750.00
# 10                     Texas City National Bank          4.5%    $2500.00
# 11  The Prudential Insurance Company of America          4.5%   $4,300.00
# 12                 THE TEXAS CITY NATIONAL BANK          4.5%   $2,400.00
# 13                         T. J. Bettes Company          4.5%    $3700.00
# 14                 The Texas City National Bank          4.5%    $2500.00
# 15                         T. J. Bettes Company          4.5%       $2500
# 16                         T. J. Bettes Company          4.5%  $11,700.00
# 17  The Lincoln National Life Insurance Company          4.5%   $4,300.00
# 18      First Mortgage Company of Houston, Inc.          4.5%   $4,950.00
# 19      First Mortgage Company of Houston, Inc.          4.5%    $3700.00
# 20      First Mortgage Company of Houston, Inc.          4.5%    $3850.00
# 21                         T. J. Bettes Company          4.5%    $2500.00
# 22  The Prudential Insurance Company of America          4.5%   $5,000.00
# 23                     J. E. Foster & Son, Inc.          4.5%   $3,950.00
# 24      FIRST MORTGAGE COMPANY OF HOUSTON, INC.          4.5%    $4100.00
#
#                                 Location_for_Mortgage  \
# 0   Lot Number Seven (7), in Block Number Four Hun...
# 1   Lot Number Eight (8), in Block Number Four Hun...
# 2   Lot Nineteen (19) of Palm Gardens, in the City...
# 3   Lots One (1), Two (2), and Three (3), Block nu...
# 4   Lots Seven (7), Eight (8) and Nine (9) in Bloc...
# 5   The East twenty feet of Lot Four (4), and the ...
# 6   Blocks Lot Thirty-five (35) in Block Three (3)...
# 7   Lots numbered Thirteen (13) and Fourteen (14),...
# 8   Lot Number Four (4) and the adjoining West one...
# 9   The East Twenty-five Feet (E-25') of Lot numbe...
# 10  Lots Nine (9) and Ten (10), Block Two Hundred ...
# 11  BEING Lot Twenty-eight (28) of Palm Gardens in...
# 12  The East one-half (E 1/2) of Lot numbered Six ...
# 13  LOTS FIFTEEN (15) and SIXTEEN (16) in BLOCK TH...
# 14  Lot One (1) and the West Thirty Feet (W-30') o...
# 15  LOT ONE (1) in BLOCK TWO (2) of the ELMO J. DU...
# 16  The East seventeen (17) feet and six (6) inche...
# 17  Lot Twelve (12) of the W. N. Zinn Resubdivisio...
# 18  Lot Four (4) in Block Three (3) in Standard Re...
# 19  Lot Number Three (3) in Block Number Four Hund...
# 20  Lots Nos. Three (3) and Four (4), in Block No....
# 21  Lot No. Twenty-one (21), of the Extension of t...
# 22  Lot Seventy-four (74) of Palm Gardens in the C...
# 23  Lot Ten (10) and the East twenty feet (20') of...
# 24  Lots Noe. Nine (9) and Ten (10), in Block No. ...
#
#                                          Payment_Plan  \
# 0   Monthly installments of $21.68 each, including...
# 1   Monthly installments of $19.74 each, including...
# 2   Monthly installments of $25.58, including inte...
# 3   Monthly payments of $22.95, including interest...
# 4   Monthly installments of $24.46 each, including...
# 5   Monthly installments of $21.96 each, including...
# 6   Monthly installments of Twenty-seven and 52/10...
# 7   Monthly installments of $20.57, commencing on ...
# 8   Monthly payments of $22.95, including interest...
# 9   Monthly payments of $21.04, including interest...
# 10  Monthly payments of $19.13, including interest...
# 11  Monthly installments of $23.91 each, including...
# 12  Monthly installments of $18.36 each, including...
# 13  Monthly installments of $23.42 each, including...
# 14  Monthly payments of $19.13, including interest...
# 15  Monthly installments of $19.13, including inte...
# 16  Monthly installments of $65.05 each, including...
# 17  Monthly installments of $23.91 each, including...
# 18  Monthly installments of $27.52, including inte...
# 19  Monthly installments of $20.57 each, including...
# 20  Monthly installments of $21.41 each, including...
# 21  Monthly installments of $19.13 each, including...
# 22  Monthly installments of $27.80 each, including...
# 23  Monthly installments of $21.96 on the first da...
# 24  Monthly installments of $22.80 each, including...
#
#     Overall_Confidence_Score Two_Mortgages           Document_Name
# 0                        0.8            No        4307375_0001.tif
# 1                        0.8            No        4307340_0001.tif
# 2                        0.9            No  48167_4000820_0001.tif
# 3                        0.9            No        4202463_0001.tif
# 4                        0.9            No        4104649_0001.tif
# 5                        0.8            No        4302425_0001.tif
# 6                        0.6            No        4305776_0001.tif
# 7                        0.9            No        4203323_0001.tif
# 8                        0.9            No        4204010_0001.tif
# 9                        0.9            No        4201768_0001.tif
# 10                       0.9            No        4104592_0001.tif
# 11                       0.9            No        4004046_0001.tif
# 12                       0.9           Yes        4004912_0001.tif
# 13                       0.9            No        4004575_0001.tif
# 14                       0.9            No        4104165_0001.tif
# 15                       0.9            No        4105565_0001.tif
# 16                       0.9           Yes        4302583_0001.tif
# 17                       0.9            No        4005813_0001.tif
# 18                       0.8           Yes        4306607_0001.tif
# 19                       0.8            No        4307353_0001.tif
# 20                       0.8            No        4205888_0001.tif
# 21                       0.9            No        4005800_0001.tif
# 22                       0.9            No        4005318_0001.tif
# 23                       0.8            No        4306964_0001.tif
# 24                       0.8           Yes        4306466_0001.tif

# %%
columns = list(df_4o_two_page.columns)
columns.remove('Overall_Confidence_Score')
columns.remove('Two_Mortgages')

# %%
columns = list(df_4o_two_page.columns)
columns.remove('Confidence_Score')
columns.remove('Two_Mortgages')

# %%
columns= ['Date', 'Borrower_First', 'Borrower_Last',
       'Second_Borrower_First', 'Second_Borrower_Last', 'Other_Party_First',
       'Other_Party_Last', 'Lending_Bank', 'Interest_Rate', 'Loan_Amount',
       'Location_for_Mortgage', 'Payment_Plan',
       'Document_Name']

# base_keys_no_conf = ['Date', 'Borrower_First', 'Borrower_Last',
#        'Second_Borrower_First', 'Second_Borrower_Last', 'Other_Party_First',
#        'Other_Party_Last', 'Lending_Bank', 'Interest_Rate', 'Loan_Amount',
#        'Location_for_Mortgage', 'Payment_Plan',
#        'Document_Name']

# %%
df_kate = df_kate[columns]


df_4o_confidence_all = df_4o_confidence_all[columns]
df_4o_confidence = df_4o_confidence[columns]
df_4o=df_4o[columns]


df_4o_mini_confidence_all = df_4o_mini_confidence_all[columns]
df_4o_mini_confidence = df_4o_mini_confidence[columns]
df_4o_mini = df_4o_mini[columns]

df_mistral_confidence = df_mistral_confidence[columns]

# %%
df_kate = df_kate[columns]

df_4o_two_page = df_4o_two_page[columns]
df_4o_two_page_refinal = df_4o_two_page_refinal[columns]
df_4o_two_page_re_refinal = df_4o_two_page_re_refinal[columns]

df_4o_mini_two_page = df_4o_mini_two_page[columns]
df_4o_mini_two_page_refinal= df_4o_mini_two_page_refinal[columns]

df_mistral_two_page = df_mistral_two_page[columns]

df_newline = df_newline[columns]

# %%
df_kate_sorted = df_kate.sort_values(by = ['Document_Name'])

df_4o_two_page_sorted = df_4o_two_page.sort_values(by = ['Document_Name'])
df_4o_two_page_sorted_refinal = df_4o_two_page_refinal.sort_values(by = ['Document_Name'])
df_4o_two_page_sorted_re_refinal = df_4o_two_page_re_refinal.sort_values(by = ['Document_Name'])

df_4o_mini_two_page_sorted = df_4o_mini_two_page.sort_values(by = 'Document_Name')
df_4o_mini_two_page_sorted_refinal = df_4o_mini_two_page_refinal.sort_values(by = 'Document_Name')

df_mistral_two_page_sorted = df_mistral_two_page.sort_values(by = ['Document_Name'])

df_newline = df_newline.sort_values(by = ['Document_Name'])
#need this cause different order

# %%
matrix, document_df, feature_df, overall = validate(df_4o_two_page_sorted, df_kate_sorted, fuzz.token_sort_ratio)
print(f'Performance for 4o: {overall}')
print(feature_df)
pd.merge(document_df, comparision_df[['Doc1', 'True']], how = 'inner', left_on = ['Document'], right_on = 'Doc1').sort_values(by = 'Score')
# Out:
# Performance for 4o: 81.24307692307693
#                   Feature   Score
# 0                    Date   50.40
# 1          Borrower_First   58.32
# 2           Borrower_Last   91.60
# 3   Second_Borrower_First   90.16
# 4    Second_Borrower_Last   92.00
# 5       Other_Party_First   66.84
# 6        Other_Party_Last   67.60
# 7            Lending_Bank   97.76
# 8           Interest_Rate   84.16
# 9             Loan_Amount   94.56
# 10  Location_for_Mortgage   93.68
# 11           Payment_Plan   69.08
# 12          Document_Name  100.00
#                   Document      Score                    Doc1 True
#
# 23        4307375_0001.tif  82.538462        4307375_0001.tif   No
# 17        4305776_0001.tif  82.538462        4305776_0001.tif   No
# 14        4205888_0001.tif  84.307692        4205888_0001.tif   No
# 7         4104592_0001.tif  85.153846        4104592_0001.tif   No
# 5         4005813_0001.tif  87.076923        4005813_0001.tif  Yes
# 24  48167_4000820_0001.tif  87.076923  48167_4000820_0001.tif   No
# 1         4004575_0001.tif  87.230769        4004575_0001.tif  Yes
# 13        4204010_0001.tif  87.615385        4204010_0001.tif   No
# 10        4201768_0001.tif  91.153846        4201768_0001.tif   No
# 11        4202463_0001.tif  92.384615        4202463_0001.tif   No
# 4         4005800_0001.tif  92.538462        4005800_0001.tif  Yes
# 20        4306964_0001.tif  92.692308        4306964_0001.tif   No
# 2         4004912_0001.tif  93.846154        4004912_0001.tif  Yes
# 8         4104649_0001.tif  94.230769        4104649_0001.tif   No

# %%
matrix, document_df, feature_df, overall = validate(df_mistral_two_page_sorted, df_kate_sorted, fuzz.token_sort_ratio)
print(f'Performance for Mistral: {overall}')
print(feature_df)
print(document_df)
# Out:
# Performance for Mistral: 78.79692307692308
#                   Feature   Score
# 0                    Date   22.60
# 1          Borrower_First   58.80
# 2           Borrower_Last   66.00
# 3   Second_Borrower_First   89.20
# 4    Second_Borrower_Last   92.60
# 5       Other_Party_First   86.52
# 6        Other_Party_Last   89.44
# 7            Lending_Bank   95.88
# 8           Interest_Rate   83.00
# 9             Loan_Amount   91.32
# 10  Location_for_Mortgage   84.80
# 11           Payment_Plan   64.20
# 12          Document_Name  100.00
#                   Document      Score
# 0         4004046_0001.tif  81.307692
# 1         4004575_0001.tif  72.769231
# 2         4004912_0001.tif  91.769231
# 3         4005318_0001.tif  80.692308
# 4         4005800_0001.tif  91.692308
# 5         4005813_0001.tif  85.923077
# 6         4104165_0001.tif  81.153846
# 7         4104592_0001.tif  83.692308
# 8         4104649_0001.tif  90.461538
# 9         4105565_0001.tif  78.692308
# 10        4201768_0001.tif  92.230769
# 11        4202463_0001.tif  94.384615
# 12        4203323_0001.tif  85.384615
# 13        4204010_0001.tif  81.538462
# 14        4205888_0001.tif  77.076923
# 15        4302425_0001.tif  68.153846
# 16        4302583_0001.tif  74.153846
# 17        4305776_0001.tif  43.538462
# 18        4306466_0001.tif  73.153846
# 19        4306607_0001.tif  70.692308
# 20        4306964_0001.tif  61.769231
# 21        4307340_0001.tif  74.692308
# 22        4307353_0001.tif  70.461538
# 23        4307375_0001.tif  77.000000
# 24  48167_4000820_0001.tif  87.538462

# %%
matrix, document_df, feature_df, overall = validate(df_4o_confidence_all, df_kate, fuzz.token_sort_ratio)
print(f'4o Overall Score {overall}')
document_df
print(feature_df)
pd.merge(document_df, comparision_df[['Doc1', 'True']], how = 'inner', left_on = ['Document'], right_on = 'Doc1').sort_values(by = 'Score')

#add deed of trust to prompt or add FHA form number to tell a model where it starts. via prompt eng
# saw output for this
# - add partial doc feature
#fall back to overall confidence approach
#ocr input must be 2 documents - have a directory within directory structure
#made changes to ocr functions for this
#then made model produce output - did sorting an all of dfs by columns to make sure they align
#this all this + validation metrics of new feature with a groud truth set and used
#the ground truth set for comparing 1 page vs 2 page approach
# Out:
# 4o Overall Score 74.6676923076923
#                   Feature   Score
# 0                    Date   44.44
# 1          Borrower_First   49.04
# 2           Borrower_Last   91.08
# 3   Second_Borrower_First   84.24
# 4    Second_Borrower_Last   88.72
# 5       Other_Party_First   75.48
# 6        Other_Party_Last   80.52
# 7            Lending_Bank   81.60
# 8           Interest_Rate   59.28
# 9             Loan_Amount   87.12
# 10  Location_for_Mortgage   81.16
# 11           Payment_Plan   48.00
# 12          Document_Name  100.00
#                   Document      Score                    Doc1 True
#
# 11        4005813_0001.tif  72.538462        4005813_0001.tif  Yes
# 19        4305776_0001.tif  72.692308        4305776_0001.tif   No
# 24        4307375_0001.tif  73.384615        4307375_0001.tif   No
# 10        4105565_0001.tif  74.384615        4105565_0001.tif   No
# 1         4204010_0001.tif  75.461538        4204010_0001.tif   No
# 12        4104165_0001.tif  79.384615        4104165_0001.tif   No
# 14        4005318_0001.tif  80.230769        4005318_0001.tif  Yes
# 3         4202463_0001.tif  81.538462        4202463_0001.tif   No
# 20        4104649_0001.tif  83.076923        4104649_0001.tif   No
# 18        4104592_0001.tif  83.153846        4104592_0001.tif   No
# 22        4203323_0001.tif  83.538462        4203323_0001.tif   No
# 8   48167_4000820_0001.tif  87.076923  48167_4000820_0001.tif   No
# 15        4004575_0001.tif  89.000000        4004575_0001.tif  Yes
# 0         4201768_0001.tif  94.153846        4201768_0001.tif   No

# %%
matrix, document_df, feature_df, overall = validate(df_newline, df_kate_sorted, fuzz.token_sort_ratio)
print(overall)
print(feature_df)
pd.merge(document_df, comparision_df[['Doc1', 'True']], how = 'inner', left_on = ['Document'], right_on = 'Doc1').sort_values(by = 'Score')
# Out:
# 78.80307692307693
#                   Feature   Score
# 0                    Date   40.44
# 1          Borrower_First   70.48
# 2           Borrower_Last   68.68
# 3   Second_Borrower_First   87.44
# 4    Second_Borrower_Last   89.92
# 5       Other_Party_First   92.36
# 6        Other_Party_Last   96.92
# 7            Lending_Bank   84.52
# 8           Interest_Rate   66.96
# 9             Loan_Amount   91.92
# 10  Location_for_Mortgage   76.80
# 11           Payment_Plan   58.00
# 12          Document_Name  100.00
#                   Document      Score                    Doc1 True
# 19        4306607_0001.tif  55.384615        4306607_0001.tif  Yes
# 18        4306466_0001.tif  55.923077        4306466_0001.tif  Yes
# 16        4302583_0001.tif  58.384615        4302583_0001.tif  Yes
# 2         4004912_0001.tif  70.461538        4004912_0001.tif  Yes
# 4         4005800_0001.tif  71.384615        4005800_0001.tif  Yes
# 5         4005813_0001.tif  72.538462        4005813_0001.tif  Yes
# 21        4307340_0001.tif  73.923077        4307340_0001.tif   No
# 23        4307375_0001.tif  74.846154        4307375_0001.tif   No
# 22        4307353_0001.tif  78.461538        4307353_0001.tif   No
# 9         4105565_0001.tif  81.076923        4105565_0001.tif   No
# 13        4204010_0001.tif  81.153846        4204010_0001.tif   No
# 3         4005318_0001.tif  81.153846        4005318_0001.tif  Yes
# 6         4104165_0001.tif  81.307692        4104165_0001.tif   No
# 17        4305776_0001.tif  81.461538        4305776_0001.tif   No
# 11        4202463_0001.tif  81.615385        4202463_0001.tif   No
# 0         4004046_0001.tif  82.692308        4004046_0001.tif   No
# 14        4205888_0001.tif  83.769231        4205888_0001.tif   No
# 15        4302425_0001.tif  84.000000        4302425_0001.tif   No
# 7         4104592_0001.tif  85.153846        4104592_0001.tif   No
# 1         4004575_0001.tif  85.692308        4004575_0001.tif  Yes
# 8         4104649_0001.tif  86.846154        4104649_0001.tif   No
# 24  48167_4000820_0001.tif  87.076923  48167_4000820_0001.tif   No
# 12        4203323_0001.tif  87.307692        4203323_0001.tif   No
# 20        4306964_0001.tif  93.461538        4306964_0001.tif   No
# 10        4201768_0001.tif  95.000000        4201768_0001.tif   No

# %%
df_newline['Document_Name']
# Out:
# 21          4004046_0001.tif
# 13          4004575_0001.tif
# 18          4004912_0001.tif
# 22          4005318_0001.tif
# 2           4005800_0001.tif
# 15          4005813_0001.tif
# 3           4104165_0001.tif
# 6           4104592_0001.tif
# 20          4104649_0001.tif
# 0           4105565_0001.tif
# 8           4201768_0001.tif
# 23          4202463_0001.tif
# 4           4203323_0001.tif
# 5           4204010_0001.tif
# 1           4205888_0001.tif
# 10          4302425_0001.tif
# 19          4302583_0001.tif
# 7           4305776_0001.tif
# 11          4306466_0001.tif
# 24          4306607_0001.tif
# 12          4306964_0001.tif
# 14          4307340_0001.tif
# 17          4307353_0001.tif
# 16          4307375_0001.tif
# 9     48167_4000820_0001.tif
# Name: Document_Name, dtype: object

# %%
df_kate['Document_Name']
# Out:
# 0           4201768_0001.tif
# 1           4204010_0001.tif
# 2           4302425_0001.tif
# 3           4202463_0001.tif
# 4           4306466_0001.tif
# 5           4302583_0001.tif
# 6           4306964_0001.tif
# 7           4205888_0001.tif
# 8     48167_4000820_0001.tif
# 9           4004912_0001.tif
# 10          4105565_0001.tif
# 11          4005813_0001.tif
# 12          4104165_0001.tif
# 13          4307340_0001.tif
# 14          4005318_0001.tif
# 15          4004575_0001.tif
# 16          4306607_0001.tif
# 17          4004046_0001.tif
# 18          4104592_0001.tif
# 19          4305776_0001.tif
# 20          4104649_0001.tif
# 21          4005800_0001.tif
# 22          4203323_0001.tif
# 23          4307353_0001.tif
# 24          4307375_0001.tif
# Name: Document_Name, dtype: object

# %%
matrix, document_df, feature_df, overall = validate(df_4o_mini_confidence, df_kate, fuzz.token_sort_ratio)
print(overall)
feature_df
# Out:
# 67.39142857142858
#                   Feature   Score
# 0                    Date   32.44
# 1          Borrower_First   53.72
# 2           Borrower_Last   68.12
# 3   Second_Borrower_First   83.36
# 4    Second_Borrower_Last   86.68
# 5       Other_Party_First   67.92
# 6        Other_Party_Last   75.40
# 7            Lending_Bank   84.52
# 8           Interest_Rate   66.96
# 9             Loan_Amount   88.80
# 10  Location_for_Mortgage   73.60
# 11           Payment_Plan   60.12
# 12          Document_Name  100.00
# 13       Confidence_Score    1.84

# %%
matrix, document_df, feature_df, overall = validate(df_4o_mini_confidence_all, df_kate, fuzz.token_sort_ratio)
print(overall)
feature_df
# Out:
# 70.43384615384615
#                   Feature   Score
# 0                    Date   24.44
# 1          Borrower_First   52.56
# 2           Borrower_Last   80.12
# 3   Second_Borrower_First   80.44
# 4    Second_Borrower_Last   82.20
# 5       Other_Party_First   63.76
# 6        Other_Party_Last   71.72
# 7            Lending_Bank   82.52
# 8           Interest_Rate   62.12
# 9             Loan_Amount   86.80
# 10  Location_for_Mortgage   71.80
# 11           Payment_Plan   57.16
# 12          Document_Name  100.00

# %%
matrix
# Out:
# array([[100, 100, 100,  91, 100, 100, 100, 100,  86, 100, 100,  87, 100],
#        [100, 100,  31, 100,  18, 100, 100,  90, 100,  80, 100,  94, 100],
#        [  0, 100,   0, 100, 100, 100, 100, 100,  86, 100,  89,  91, 100],
#        [100, 100, 100, 100, 100, 100, 100, 100,  86, 100, 100,  91, 100],
#        [  0,   6,  36, 100, 100, 100, 100,  10,   0,  77,  97,   2, 100],
#        [  0, 100,   0,   0,   0, 100, 100, 100,  86, 100, 100,  85, 100],
#        [  0,   0,   0, 100, 100,  29,  29, 100,  86, 100, 100,  91, 100],
#        [  0, 100,  44, 100, 100, 100, 100, 100,  86,  93, 100,  90, 100],
#        [  0, 100, 100, 100, 100, 100, 100, 100,  86,  93, 100,  91, 100],
#        [ 63, 100, 100, 100, 100, 100, 100,  29,   0,  80,  73,   2, 100],
#        [  0, 100,  17, 100, 100, 100, 100, 100,  86,  93,  97,  93, 100],
#        [  0, 100, 100, 100, 100, 100, 100, 100,   0, 100, 100,   2, 100],
#        [  0, 100, 100, 100, 100,  67, 100, 100,  86,  93, 100,  91, 100],
#        [  0, 100,  44, 100, 100, 100,  93, 100,  86,  93, 100,  91, 100],
#        [  0, 100, 100, 100, 100, 100, 100, 100,  86, 100, 100,  91, 100],
#        [  0,  55, 100, 100, 100, 100, 100, 100,  86,  93, 100,  91, 100],
#        [  0,   0,   0, 100, 100,   0,  25,  10,   0,  62,  86,   2, 100],
#        [  0, 100,  80,  80,  80, 100, 100, 100,  86, 100, 100,  91, 100],
#        [  0, 100, 100, 100, 100, 100, 100, 100,  86,  93, 100,  91, 100],
#        [  0,   9,   0,   0,   0,  25,  15,  18,  57,  33,  62,  80, 100],
#        [  0, 100, 100, 100, 100, 100, 100, 100,  86, 100, 100,  91, 100],
#        [ 74, 100, 100, 100, 100, 100, 100,  19,   0,  62, 100,   2, 100],
#        [  0, 100,  88, 100, 100, 100, 100, 100,  86, 100, 100,  82, 100],
#        [  0, 100,  44, 100, 100, 100, 100, 100,  86,  93, 100,  89, 100],
#        [  0, 100,  44, 100, 100, 100, 100, 100,  86,  93, 100,  89, 100]])

# %%
df_mistral_confidence
# Out:
#           Date Borrower_First Borrower_Last Second_Borrower_First  \
# 0   28/10/1941         Palmer        Haynes                 Ilene
# 1    22/4/1942          Elmer       Douglas                  Edna
# 2     1/1/1943           Home      Builders                   NaN
# 3   24/12/1941         George       Clayton                   NaN
# 4    3/11/1943          J. D.      Townsend                   NaN
# 5    19/1/1942          W. E.         White                Louise
# 6     1/1/1960              J        Foster                   NaN
# 7       2/1/42          J. L.        MARTIN                   NaN
# 8     1/1/1935          L. B.        Berndt            Mary Ellen
# 9   16/09/1940         Kermit          Agee              Margaret
# 10    2/1/1941         Marvin         Burke                  Lela
# 11  31/10/1940       Lawrence       McLaren                Louise
# 12    5/3/1941       Margaret         Noble                   NaN
# 13   12/1/1942              J        MARTIN                   NaN
# 14   11/1/1940         Vester         Roper                 Naomi
# 15  18/04/1939          T. F.  HIGGINBOTHAM                 Hazel
# 16  17/11/1943              J      Hestwood                   NaN
# 17    1/1/1940           A.W.         Koore                 Label
# 18   12/3/1941           Carl          Rust                 Louie
# 19    1/1/1930           John           Doe                   Tim
# 20    1/1/1941       Clarence         Quinn              Kathleen
# 21  29/10/1940          C. A.      Robinson                Bessie
# 22    8/1/1942              R      MOCAULEY                   NaN
# 23   12/1/1942              J        MARTIN                   NaN
# 24   12/1/1942              J        MARTIN                   NaN
#
#    Second_Borrower_Last Other_Party_First Other_Party_Last  \
# 0                Haynes             R. M.             Orth
# 1                 Pearl              R.M.             Orth
# 2                   NaN              J.E.           Foster
# 3                   NaN             R. M.             Orth
# 4                   NaN             J. G.         Hestwood
# 5                  Cook             T. J.           Bettes
# 6                   NaN              Home         Builders
# 7                   NaN             J. G.         HESTWOOD
# 8                Berndt            Wm. S.          Bradley
# 9                  Agee             R. M.             Orth
# 10              Peeples             T. J.           Bettes
# 11              McLaren             Harry            Ninde
# 12                  NaN             I. M.             Orth
# 13                  NaN              J.G.          ESTWOOD
# 14                Roper           Carroll            Jones
# 15         HIGGINBOTHAM             T. J.           BETTES
# 16                  NaN             Plumb         Mitchell
# 17                Koore           Carroll            Jones
# 18               Godard             R. M.             Orth
# 19                 Cook             Jamie            Patel
# 20                Quinn                 B           Yeager
# 21             Robinson             T. J.           Bettes
# 22                  NaN                 R             ORTH
# 23                  NaN                 J         HESTWOOD
# 24                  NaN                 J         HESTWOOD
#
#                                          Lending_Bank Interest_Rate  \
# 0                        THE TEXAS CITY NATIONAL BANK          4.5%
# 1                             THE TEXAS NATIONAL BANK            4%
# 2                            J. E. FOSTER & SON, INC.          4.5%
# 3                        THE TEXAS CITY NATIONAL BANK          4.5%
# 4                                                 NaN           NaN
# 5                                T. J. BETTES COMPANY          4.5%
# 6                             J. E.Foster & Son, Inc.          4.5%
# 7             FIRST MORTGAGE COMPANY OF HOUSTON, INC.          4.5%
# 8                     Mortgage Investment Corporation          4.5%
# 9   FHA - For Use Under Title I Class 3 Loans on L...           NaN
# 10                               T. J. Bettes Company          4.5%
# 11        The Lincoln National Life Insurance Company           NaN
# 12                       THE TEXAS CITY NATIONAL BANK          4.5%
# 13            FIRST MORTGAGE COMPANY OF HOUSTON, INC.          4.5%
# 14        THE PRUDENTIAL INSURANCE COMPANY OF AMERICA          4.5%
# 15                               T. J. BETTES COMPANY          4.5%
# 16                                                NaN           NaN
# 17        THE PRUDENTIAL INSURANCE COMPANY OF AMERICA          4.5%
# 18                       THE TEXAS CITY NATIONAL BANK          4.5%
# 19                                           ABC Bank          3.5%
# 20                  Gulf Coast Investment Corporation          4.5%
# 21                                                NaN           NaN
# 22                           TEXAS CITY NATIONAL BANK          4.5%
# 23            FIRST MORTGAGE COMPANY OF HOUSTON, INC.          4.5%
# 24            FIRST MORTGAGE COMPANY OF HOUSTON, INC.          4.5%
#
#    Loan_Amount                              Location_for_Mortgage  \
# 0    $2,750.00  The East Twenty-five Feet (E-25') of Lot numbe...
# 1     $3000.00  Lot Number Four (4) and the adjoining West one...
# 2    $3,950.00  The East twenty feet of Lot Four (4), and the ...
# 3    $3,000.00  Lots One (1), Two (2), and Three (3), Block nu...
# 4       $10.00  Lots Noe. Nine (9) and Ten (10), in Block No. ...
# 5   $11,700.00  The East seventeen (17) feet and six (6) inche...
# 6    $3,950.00  Lot Ten (10) and the East twenty feet (20') of...
# 7     $3850.00  Lots Nos. Three (3) and Four (4), in Block No....
# 8     $4600.00  Lot Nineteen (19) of Palm Gardens, in the City...
# 9     $2000.00  Lot Three (3) in Block One Hundred Forty-six (...
# 10    $2500.00  Lot One (1) in Block Two (2) of the Elmo J. Du...
# 11   $4,300.00  Lot Twelve (12) of the W. N. Zinn Resubdivisio...
# 12    $2500.00  Lot One (1) and the West Thirty Feet (W-30') o...
# 13    $3550.00  Lot Number Eight (8), in Block Number Four Hun...
# 14   $5,000.00  Lot Seventy-four (74) of Palm Gardens in the C...
# 15    $3700.00  LOTS FIFTEEN (15) and SIXTEEN (16) in BLOCK TH...
# 16      $10.00  Lot Four (4) in Block Three (3) in Standard Re...
# 17   $4,300.00  Lot Twenty-eight (28) of Palm Gardens in the C...
# 18    $2500.00  Lots Nine (9) and Ten (10), Block Two Hundred ...
# 19       $2500  Lot Seven (7) and the East Forty Feet (e-4') O...
# 20   $4,400.00  Lots Seven (7), Eight (8) and Nine (9) in Bloc...
# 21      $10.00  Lot No. Twenty-one (21), of the Extension of t...
# 22   $3,250.00  Lots numbered Thirteen (13) and Fourteen (14),...
# 23    $3700.00  Lot Number Three (3) in Block Number Four Hund...
# 24    $3900.00  Lot Number Seven (7), in Block Number Four Hun...
#
#                                          Payment_Plan           Document_Name
# 0   Monthly payments of $21.04, including interest...        4201768_0001.tif
# 1   Monthly payments of $22.95, including interest...        4204010_0001.tif
# 2   Monthly payments of $21.96, including interest...        4302425_0001.tif
# 3   Monthly payments of $22.95, including interest...        4202463_0001.tif
# 4                                                 NaN        4306466_0001.tif
# 5   Monthly payments of $65.05, including interest...        4302583_0001.tif
# 6   Monthly payments of $21.96, including interest...        4306964_0001.tif
# 7   Monthly payments of $21.41, including interest...        4205888_0001.tif
# 8   Monthly payments of $25.58, including interest...  48167_4000820_0001.tif
# 9                                                 NaN        4004912_0001.tif
# 10  Monthly payments of $19.13, including interest...        4105565_0001.tif
# 11                                                NaN        4005813_0001.tif
# 12  Monthly payments of $19.13, including interest...        4104165_0001.tif
# 13  Monthly payments of $19.74, including interest...        4307340_0001.tif
# 14  Monthly payments of $27.80, including interest...        4005318_0001.tif
# 15  Monthly payments of $23.42, including interest...        4004575_0001.tif
# 16                                                NaN        4306607_0001.tif
# 17  Monthly payments of $23.91, including interest...        4004046_0001.tif
# 18  Monthly payments of $19.13, including interest...        4104592_0001.tif
# 19  Monthly payments of $19.20, including interest...        4305776_0001.tif
# 20  Monthly payments of $24.46, including interest...        4104649_0001.tif
# 21                                                NaN        4005800_0001.tif
# 22  Monthly payments of $20.57, including interest...        4203323_0001.tif
# 23  Monthly payments of $20.57, including interest...        4307353_0001.tif
# 24  Monthly payments of $21.68, including interest...        4307375_0001.tif

# %%
df_kate
# Out:
#           Date                   Borrower_First Borrower_Last  \
# 0   10/28/1941                       Palmer T.         Haynes
# 1    4/22/1942                    Elmer Douglas        Laiche
# 2          NaN              Home Builders, Inc.           NaN
# 3   12/24/1941                        George L.       Clayton
# 4          NaN    Townsend Construction Company           NaN
# 5          NaN                W.E. White, Inc.            NaN
# 6          NaN              Home Builders, Inc.           NaN
# 7          NaN  J. L. Martin Investment Company           NaN
# 8          NaN                             L.B.        Berndt
# 9    9/12/1940                       Kermit E.           Agee
# 10         NaN                     Marvin Burke       Peeples
# 11         NaN                      Lawrence G.       McLaren
# 12         NaN                     Margaret E.          Noble
# 13         NaN  J. L. Martin Investment Company           NaN
# 14         NaN                        Vester L.         Roper
# 15         NaN                       Thomas F.   Higginbotham
# 16         NaN            Plumb-Mitchell, Inc.            NaN
# 17         NaN                           A. W.          Moore
# 18         NaN                         Carl A.           Rust
# 19         NaN            Plumb-Mitchell, Inc.            NaN
# 20         NaN                 Clarence Francis         Quinn
# 21   7/11/1940                            C. A.      Robinson
# 22         NaN                           R. V.       McCauley
# 23         NaN  J. L. Martin Investment Company           NaN
# 24         NaN  J. L. Martin Investment Company           NaN
#
#    Second_Borrower_First Second_Borrower_Last Other_Party_First  \
# 0                 Ilenes               Haynes            R. M.
# 1             Edna Pearl               Laiche            R. M.
# 2                    NaN                  NaN             J.E.
# 3                    NaN                  NaN            R. M.
# 4                    NaN                  NaN              J.G.
# 5                    NaN                  NaN            T. J.
# 6                    NaN                  NaN             J.E.
# 7                    NaN                  NaN              J.G.
# 8             Mary Ellen               Berndt           Wm. S.
# 9               Margaret                 Agee            R. M.
# 10              Lela G.               Peeples            T. J.
# 11             Louise A.              McLaren             Harry
# 12                   NaN                  NaN            R. M.
# 13                   NaN                  NaN              J.G.
# 14             Naomi R.                 Roper        Carroll L.
# 15                 Hazel         Higginbotham            T. J.
# 16                   NaN                  NaN              J.G.
# 17                 Mabel                Moore        Carroll L.
# 18             Louie D.                Godard            R. M.
# 19                   NaN                  NaN              J.G.
# 20             Kathleen                 Quinn              B.B.
# 21                Bessie             Robinson            T. J.
# 22                   NaN                  NaN            R. M.
# 23                   NaN                  NaN              J.G.
# 24                   NaN                  NaN              J.G.
#
#    Other_Party_Last                                 Lending_Bank  \
# 0              Orth                     Texas City National Bank
# 1              Orth                     Texas City National Bank
# 2            Foster                     J.E. Foster & Son, Inc.
# 3              Orth                     Texas City National Bank
# 4          Hestwood     First Mortgage Company of Houston, Inc.
# 5            Bettes                         T. J. Bettes Company
# 6            Foster                     J.E. Foster & Son, Inc.
# 7          Hestwood     First Mortgage Company of Houston, Inc.
# 8           Bradley              Mortgage Investment Corporation
# 9              Orth                     Texas City National Bank
# 10           Bettes                         T. J. Bettes Company
# 11            Ninde  The Lincoln National Life Insurance Company
# 12             Orth                     Texas City National Bank
# 13         Hestwood     First Mortgage Company of Houston, Inc.
# 14            Jones      Prudential Insurance Company of America
# 15           Bettes                         T. J. Bettes Company
# 16         Hestwood     First Mortgage Company of Houston, Inc.
# 17            Jones  The Prudential Insurance Company of America
# 18             Orth                 The Texas City National Bank
# 19         Hestwood     First Mortgage Company of Houston, Inc.
# 20           Yeager            Gulf Coast Investment Corporation
# 21           Bettes                         T. J. Bettes Company
# 22             Orth                     Texas City National Bank
# 23         Hestwood     First Mortgage Company of Houston, Inc.
# 24         Hestwood     First Mortgage Company of Houston, Inc.
#
#    Interest_Rate Loan_Amount  \
# 0          4.50%   $2,750.00
# 1          4.50%   $3,000.00
# 2          4.50%   $3,950.00
# 3          4.50%   $3,000.00
# 4          4.50%   $4,100.00
# 5          4.50%  $11,700.00
# 6          4.50%   $3,950.00
# 7          4.50%   $3,850.00
# 8          4.50%   $4,600.00
# 9          4.50%   $2,400.00
# 10         4.50%   $2,500.00
# 11         4.50%   $4,300.00
# 12         4.50%   $2,500.00
# 13         4.50%   $3,550.00
# 14         4.50%   $5,000.00
# 15         4.50%   $3,700.00
# 16         4.50%   $4,950.00
# 17         4.50%   $4,300.00
# 18         4.50%   $2,500.00
# 19         4.50%   $4,950.00
# 20         4.50%   $4,400.00
# 21         4.50%   $2,500.00
# 22         4.50%   $3,250.00
# 23         4.50%   $3,700.00
# 24         4.50%   $3,900.00
#
#                                 Location_for_Mortgage  \
# 0   The East Twenty-five Feet (E-25') of Lot numbe...
# 1   Lot Number Four (4) and the adjoining West one...
# 2   The East twenty (20) feet of Lot Three (3), al...
# 3   Lots One (1), Two (2), and Three (3), Block nu...
# 4   Lots Nos. Nine (9) and Ten (10), in Block No. ...
# 5   The East seventeen (17) feet and six (6) inche...
# 6   Lot Ten (10) and the East twenty feet (20') of...
# 7   Lots Nos. Three (3) and Four (4), in Block No....
# 8   Lot Nineteen (19) of Palm Gardens, in the City...
# 9   The East one-half (E 1/2) of Lot numbered Six ...
# 10  LOT ONE (1) in BLOCK TWO (2) of the ELMO J. DU...
# 11  Lot Twelve (12) of the W. N. Zinn Resubdivisio...
# 12  Lot One (1) and the West Thirty Feet (W-30') o...
# 13  Lot Number Eight (8) in Block Number Four Hund...
# 14  BEING Lot Seventy-four (74) of Palm Gardens in...
# 15  Lots Fifteen (15) and Sixteen (16) in Block Th...
# 16  Lot Four (4) in Block Three (3) in Standard Re...
# 17  BEING Lot Twenty-eight (28) of Palm Gardens in...
# 18  Lots Nine (9) and Ten (10), Block Two Hundred ...
# 19  Lot Thirty-five (35) in Block Three (3), Stand...
# 20  Lots Seven (7), Eight (8), and Nine (9) in Blo...
# 21  Lot No. Twenty-one (21) of the Extension of th...
# 22  Lots numbered Thirteen (13) and Fourteen (14),...
# 23  Lot Number Three (3) in Block Number Four Hund...
# 24  Lot Number Seven (7), in Block Number Four Hun...
#
#                                          Payment_Plan           Document_Name
# 0   monthly installments of twenty one & 04/100 do...        4201768_0001.tif
# 1   monthly installments of twenty two & 95/100 do...        4204010_0001.tif
# 2   monthly installments of Twenty-one and 96/100 ...        4302425_0001.tif
# 3   monthly installments of twenty-two & 95/100 Do...        4202463_0001.tif
# 4   monthly installments of Twenty-two and 80/100 ...        4306466_0001.tif
# 5   monthly installments of sixty-five and 05/100 ...        4302583_0001.tif
# 6   monthly installments of Twenty-one and 96/100 ...        4306964_0001.tif
# 7   monthly installments of Twenty-one and 41/100 ...        4205888_0001.tif
# 8   monthly installments of twenty-five and 58/100...  48167_4000820_0001.tif
# 9   monthly installments of eighteen & 36/100 Doll...        4004912_0001.tif
# 10  monthly installments of nineteen & 13/100 Doll...        4105565_0001.tif
# 11  monthly installments of Twenty-three and 91/10...        4005813_0001.tif
# 12  monthly installments of nineteen & 13/100 Doll...        4104165_0001.tif
# 13  monthly installments of Nineteen and 74/100 Do...        4307340_0001.tif
# 14  monthly installments of Twenty-Seven and 80/10...        4005318_0001.tif
# 15  monthly installments of TWENTY THREE AND 42/10...        4004575_0001.tif
# 16  monthly installments of Twenty-seven and 52/10...        4306607_0001.tif
# 17  monthly installments of TWENTY-THREE and 91/10...        4004046_0001.tif
# 18  monthly installments of NINETEEN & 13/100 Doll...        4104592_0001.tif
# 19  monthly installments of Twenty-seven and 52/10...        4305776_0001.tif
# 20  monthly installments of Twenty-four and 46/100...        4104649_0001.tif
# 21  monthly installments of Nineteen and 13/100 Do...        4005800_0001.tif
# 22  monthly installments, commencing on the first ...        4203323_0001.tif
# 23  monthly installments of Twenty and 57/100 Doll...        4307353_0001.tif
# 24  monthly installments of Twenty-one and 68/100 ...        4307375_0001.tif

# %%
matrix, document_df, feature_df, overall = validate(df_4o_confidence, df_4o_confidence_all, fuzz.token_sort_ratio)
overall
# Out:
# 86.79714285714286

# %%
matrix, document_df, feature_df, overall = validate(df_4o_mini_confidence, df_4o_mini_confidence_all, fuzz.token_sort_ratio)
overall
# Out:
# 86.48857142857143

# %%
matrix, document_df, feature_df, overall = validate(df_4o, df_4o_confidence_all[columns[:-1]], fuzz.token_sort_ratio)
overall
# Out:
# 86.59076923076923

# %%
matrix, document_df, feature_df, overall = validate(df_4o_mini, df_4o_mini_confidence_all[columns[:-1]], fuzz.token_sort_ratio)
overall
# Out:
# 89.73846153846154

# %%
matrix, document_df, feature_df, overall = validate(df_4o, df_4o_confidence[columns[:-1]], fuzz.token_sort_ratio)
overall
# Out:
# 87.92307692307692

# %%
matrix, document_df, feature_df, overall = validate(df_4o_mini, df_4o_mini_confidence[columns[:-1]], fuzz.token_sort_ratio)
overall
# Out:
# 91.05230769230769

# %%
text1 = ''
text2 = "Name .. is my Uday"

token_set_ratio = fuzz.token_set_ratio(text1, text2)
token_set_ratio
# Out:
# 100

# %% [markdown]
# # Ratio Playground
#
# 1. **Ratio** - Levenstein Distance
#
#
# 2. **Partial Ratio** - Substring Matching (If one is a substring of the larger then 100)
#
# 3. **Token_Sort_Ratio** - Texts are tokenized and then alphabetically sorted. Then Levenstein distance is computed.
#
# 4. **Token_Set_Ratio** - Tokenization + Partial String Matching + Levenstein (So tokenize, preprocess, find common, then calculate Levenstein).

# %%
ratio = fuzz.ratio(df_4o['Borrower_First'][0], df_4o_mini['Borrower_First'][0])
ratio

#had to make two moves from a set of (add, delete, subsitute)
# Out:
# 80

# %%
df_4o['Borrower_First'][0]
# Out:
# 'Palmer'

# %%
df_4o_mini['Borrower_First'][0]
# Out:
# 'Palmer T.'

# %%
partial_ratio = fuzz.partial_ratio(df_4o['Borrower_First'][0], df_4o_mini['Borrower_First'][0])
partial_ratio

#found matching string so 100
# Out:
# 100

# %%
token_sort_ratio = fuzz.token_sort_ratio(df_4o['Borrower_First'][0], df_4o_mini['Borrower_First'][0])
token_sort_ratio

#preprocessing probably removed the . so more than ratio
# Out:
# 86

# %%
token_set_ratio = fuzz.token_set_ratio(df_4o['Borrower_First'][0], df_4o_mini['Borrower_First'][0])
token_set_ratio

#tokenization + partial gives 100 again
# Out:
# 100
